# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # First Experiment

# %%
df = pd.read_csv("experiments_data/standard_behaviour.csv")
df = df.rename(columns={"Unnamed: 0": "Timestep", "0": "Force (Unitless)"})
df.head()
# Out:
#    Timestep  Force (Unitless)
# 0         0         63.305822
# 1         1         64.851328
# 2         2         67.772961
# 3         3         67.231752
# 4         4         65.189941

# %%
df["Filtered Force (Unitless)"] = df["Force (Unitless)"].rolling(20).mean()
df["STD Force (Unitless)"] = df["Force (Unitless)"].rolling(20).std()
df[["Force (Unitless)", "Filtered Force (Unitless)"]].plot(title="Expected behaviour ", xlabel="Timestep", ylabel="Force (Unitless)", grid=True)
# Out:
# <Axes: title={'center': 'Expected behaviour '}, xlabel='Timestep', ylabel='Force (Unitless)'>

# %%
#sns.set(rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'})
sns.set_style("whitegrid")
timestep = df["Timestep"]
gross_force = df["Force (Unitless)"] 
filtered_force = df["Filtered Force (Unitless)"]
std = df["STD Force (Unitless)"]

plt.title("Applied disturbances: Center area")
plt.plot(timestep, gross_force, 'r--', label='Gross')
plt.plot(timestep, filtered_force, 'k-', label='Filtered')
plt.fill_between(timestep, filtered_force - std, filtered_force + std, color='k', alpha=0.3)
plt.grid(visible=True, linewidth=1)
plt.xlabel("Timestep")
plt.ylabel("Force (Unitless)")
plt.legend(title='Force')


#plt.show()

# %% [markdown]
# # Second Experiment

# %%
df = pd.read_csv("experiments_data/standard_behaviour_2.csv")
df = df.rename(columns={"Unnamed: 0": "Timestep", "0": "Force (Unitless)"})
df.head()
# Out:
#    Timestep  Force (Unitless)
# 0         0         62.273308
# 1         1         63.122164
# 2         2         53.733323
# 3         3         44.021720
# 4         4         33.740082

# %%
df["Filtered Force (Unitless)"] = df["Force (Unitless)"].rolling(20).mean()
df["STD Force (Unitless)"] = df["Force (Unitless)"].rolling(20).std()
df[["Force (Unitless)", "Filtered Force (Unitless)"]].plot(title="Expected behaviour ", xlabel="Timestep", ylabel="Force (Unitless)", grid=True)
# Out:
# <Axes: title={'center': 'Expected behaviour '}, xlabel='Timestep', ylabel='Force (Unitless)'>

# %%
#sns.set(rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'})
sns.set_style("whitegrid")
timestep = df["Timestep"]
gross_force = df["Force (Unitless)"] 
filtered_force = df["Filtered Force (Unitless)"]
std = df["STD Force (Unitless)"]

plt.title("Applied disturbance: Center area")
plt.plot(timestep, gross_force, 'r--', label='Gross')
plt.plot(timestep, filtered_force, 'k-', label='Filtered')
plt.fill_between(timestep, filtered_force - std, filtered_force + std, color='k', alpha=0.3)
plt.grid(visible=True, linewidth=1)
plt.xlabel("Timestep")
plt.ylabel("Force (Unitless)")
plt.legend(title='Force')


#plt.show()

# %% [markdown]
# # EXPERIMENT WITH PID: REACHING SETPOINT (Openning)

# %%
df = pd.read_csv("experiments_data/control_demo_4.csv")
df = df.rename(columns={"Unnamed: 0": "Timestep", "error`": "error"})
df["STD filter_measure_variable"] = df["gross_measure_variable"].rolling(20).std()
df.head()
# Out:
#    Timestep  set_point  filter_measure_variable  gross_measure_variable  \
# 0         0         80                71.671488               71.425582
# 1         1         80                72.654895               74.621710
# 2         2         80                72.884669               73.573992
# 3         3         80                72.385640               70.389523
# 4         4         80                73.061494               76.440761
#
#       error  STD filter_measure_variable
# 0  8.328512                          NaN
# 1  7.345105                          NaN
# 2  7.115331                          NaN
# 3  7.614360                          NaN
# 4  6.938506                          NaN

# %%
#sns.set(rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'})
sns.set_style("whitegrid")

timestep = df["Timestep"]
set_point = df["set_point"]
gross_force = df["gross_measure_variable"] 
filtered_force = df["filter_measure_variable"]
std = df["STD filter_measure_variable"]

plt.title("Tactile surface pressed at C")
#plt.plot(timestep, set_point, 'g-', label='Setpoint')
plt.plot(timestep, gross_force, 'r--', label='Gross')
plt.plot(timestep, filtered_force, 'k-', label='Filtered')
plt.fill_between(timestep, filtered_force - std, filtered_force + std, color='k', alpha=0.3)
plt.grid(visible=True, linewidth=1)
plt.xlabel("Timestep")
plt.ylabel("Force (Unitless)")
plt.legend(title='Force')


#plt.show()

# %% [markdown]
# # EXPERIMENT WITH PID: REACHING SETPOINT (Graspping)

# %%
df = pd.read_csv("experiments_data/control_demo_5.csv")
df = df.rename(columns={"Unnamed: 0": "Timestep", "error`": "error"})
df["STD filter_measure_variable"] = df["gross_measure_variable"].rolling(20).std()
df.head()
# Out:
#    Timestep  set_point  filter_measure_variable  gross_measure_variable  \
# 0         0        150                41.740591               42.742621
# 1         1        150                41.493252               40.998576
# 2         2        150                41.271927               40.607952
# 3         3        150                41.457885               42.201717
# 4         4        150                41.279463               40.387350
#
#         error  STD filter_measure_variable
# 0  108.259409                          NaN
# 1  108.506748                          NaN
# 2  108.728073                          NaN
# 3  108.542115                          NaN
# 4  108.720537                          NaN

# %%
sns.set(rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'})
sns.set_style("whitegrid")

timestep = df["Timestep"]
set_point = df["set_point"]
gross_force = df["gross_measure_variable"] 
filtered_force = df["filter_measure_variable"]
std = df["STD filter_measure_variable"]

plt.title("Object grasped from: Center")
#plt.plot(timestep, set_point, 'g-', label='Setpoint')
plt.plot(timestep, gross_force, 'r--', label='Gross')
plt.plot(timestep, filtered_force, 'k-', label='Filtered')
plt.fill_between(timestep, filtered_force - std, filtered_force + std, color='k', alpha=0.3)
plt.grid(visible=True, linewidth=1)
plt.xlabel("Timestep")
plt.ylabel("Force (Unitless)")
plt.legend(title='Force')


#plt.show()

# %% [markdown]
# # EXPERIMENT WITH PID: REACHING SETPOINT (Graspping Corner)

# %%
## TEST 6-8
df = pd.read_csv("experiments_data/control_demo_7.csv")
df = df.rename(columns={"Unnamed: 0": "Timestep", "error`": "error"})
df["STD filter_measure_variable"] = df["gross_measure_variable"].rolling(20).std()
df.head()
# Out:
#    Timestep  set_point  filter_measure_variable  gross_measure_variable  \
# 0         0        150                80.477514               80.618432
# 1         1        150                80.179665               79.583968
# 2         2        150                79.458457               77.294834
# 3         3        150                81.189555               88.113944
# 4         4        150                80.706287               78.289946
#
#        error  STD filter_measure_variable
# 0  69.522486                          NaN
# 1  69.820335                          NaN
# 2  70.541543                          NaN
# 3  68.810445                          NaN
# 4  69.293713                          NaN

# %%
#sns.set(rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'})
sns.set_style("whitegrid")

timestep = df["Timestep"]
set_point = df["set_point"]
gross_force = df["gross_measure_variable"] 
filtered_force = df["filter_measure_variable"]
std = df["STD filter_measure_variable"]

plt.title("Object grasped from: Edge corner")
#plt.plot(timestep, set_point, 'g-', label='Setpoint')
plt.plot(timestep, gross_force, 'r--', label='Gross')
plt.plot(timestep, filtered_force, 'k-', label='Filtered')
plt.fill_between(timestep, filtered_force - std, filtered_force + std, color='k', alpha=0.3)
plt.grid(visible=True, linewidth=1)
plt.xlabel("Timestep")
plt.ylabel("Force (Unitless)")
plt.legend(title='Force')


#plt.show()

# %%
## TEST 6-8
df = pd.read_csv("experiments_data/control_demo_6.csv")
df = df.rename(columns={"Unnamed: 0": "Timestep", "error`": "error"})
df["STD filter_measure_variable"] = df["gross_measure_variable"].rolling(20).std()
df.head()
# Out:
#    Timestep  set_point  filter_measure_variable  gross_measure_variable  \
# 0         0         90                80.447292               80.176931
# 1         1         90                79.987022               79.066482
# 2         2         90                80.453072               81.851221
# 3         3         90                80.080237               78.588897
# 4         4         90                81.414916               88.088310
#
#        error  STD filter_measure_variable
# 0   9.552708                          NaN
# 1  10.012978                          NaN
# 2   9.546928                          NaN
# 3   9.919763                          NaN
# 4   8.585084                          NaN

# %%
#sns.set(rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'})
sns.set_style("whitegrid")

timestep = df["Timestep"]
set_point = df["set_point"]
gross_force = df["gross_measure_variable"] 
filtered_force = df["filter_measure_variable"]
std = df["STD filter_measure_variable"]

plt.title("Object grasped from: Vertical edge")
#plt.plot(timestep, set_point, 'g-', label='Setpoint')
plt.plot(timestep, gross_force, 'r--', label='Gross')
plt.plot(timestep, filtered_force, 'k-', label='Filtered')
plt.fill_between(timestep, filtered_force - std, filtered_force + std, color='k', alpha=0.3)
plt.grid(visible=True, linewidth=1)
plt.xlabel("Timestep")
plt.ylabel("Force (Unitless)")
plt.legend(title='Force')


#plt.show()

# %%
## TEST 6-8
df = pd.read_csv("experiments_data/control_demo_8.csv")
df = df.rename(columns={"Unnamed: 0": "Timestep", "error`": "error"})
df["STD filter_measure_variable"] = df["gross_measure_variable"].rolling(20).std()
df.head()

#sns.set(rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'})
sns.set_style("whitegrid")

timestep = df["Timestep"]
set_point = df["set_point"]
gross_force = df["gross_measure_variable"] 
filtered_force = df["filter_measure_variable"]
std = df["STD filter_measure_variable"]

plt.title("Object grasped from: surface")
#plt.plot(timestep, set_point, 'g-', label='Setpoint')
plt.plot(timestep, gross_force, 'r--', label='Gross')
plt.plot(timestep, filtered_force, 'k-', label='Filtered')
plt.fill_between(timestep, filtered_force - std, filtered_force + std, color='k', alpha=0.3)
plt.grid(visible=True, linewidth=1)
plt.xlabel("Timestep")
plt.ylabel("Force (Unitless)")
plt.legend(title='Force')


#plt.show()
