# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.get_backend()
# Out:
# 'module://matplotlib_inline.backend_inline'

# %%
# %matplotlib widget
matplotlib.rcParams['figure.figsize'] = [15, 10]

# %%
df = pd.read_csv("zn_test1.csv")
df.head()
# Out:
#        time  set_point  filter_measure_variable  gross_measure_variable  \
# 0  0.028935         10                12.866657               12.866657
# 1  0.053787         10                12.866657               12.866657
# 2  0.078573         10                13.016315               13.315630
# 3  0.103804         10                13.091144               13.315630
# 4  0.128536         10                13.136041               13.315630
#
#       error
# 0 -2.866657
# 1 -2.866657
# 2 -3.315630
# 3 -3.315630
# 4 -3.315630

# %%
plt.figure()
plt.plot(df["time"], df["set_point"])
plt.plot(df["time"], df["gross_measure_variable"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Tu = 34.62-32.23 
Ku = 0.00075

Kp = 0.2*Ku
Ki = 0.4*Ku/Tu
Kd = 0.066*Ku*Tu

print(f"{Kp=} \t {Ki=} \t {Kd=}")
# Out:
# Kp=0.00015000000000000001 	 Ki=0.00012552301255230124 	 Kd=0.00011830500000000004

# %% [markdown]
# # Results

# %%
df2 = pd.read_csv("zn_pid_tuned_test1.csv")
plt.figure()
plt.plot(df2["time"], df2["set_point"])
plt.plot(df2["time"], df2["gross_measure_variable"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df2 = pd.read_csv("zn_pid_tuned_test2.csv")
plt.figure()
plt.plot(df2["time"], df2["set_point"])
plt.plot(df2["time"], df2["gross_measure_variable"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df2.head()
# Out:
#        time  set_point  filter_measure_variable  filter_measure_variable_2  \
# 0  0.019384          5                13.635766                   0.020467
# 1  0.044416          5                13.635766                   0.160291
# 2  0.069283          5                13.635766                   0.614952
# 3  0.094186          5                11.381035                   1.575488
# 4  0.119286          5                10.008900                   3.091654
#
#    gross_measure_variable     error
# 0               13.635766  4.979533
# 1               13.635766  4.839709
# 2               13.635766  4.385048
# 3                4.616840  3.424512
# 4                4.520362  1.908346

# %%
Tu = 34.62-32.23 
Kp = 0.00015
df2 = pd.read_csv("zn_pid_tuned_test3.csv")
plt.figure()
plt.plot(df2["time"], df2["set_point"])
plt.plot(df2["time"], df2["gross_measure_variable"])
plt.plot(df2["time"], df2["filter_measure_variable"])
#plt.plot(df2["time"], df2["filter_measure_variable_2"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Tu = 34.62-32.23 
Kp = 0.00025
Kd = 0.0000005#*Ku*Tu

df2 = pd.read_csv("zn_pid_tuned_test4.csv")
plt.figure()
plt.plot(df2["time"], df2["set_point"])
plt.plot(df2["time"], df2["gross_measure_variable"])
plt.plot(df2["time"], df2["filter_measure_variable"])
#plt.plot(df2["time"], df2["filter_measure_variable_2"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Tu = 34.62-32.23 
Kp = 0.00025
Kd = 0.0000005#*Ku*Tu

df2 = pd.read_csv("zn_pid_tuned_test5.csv")
plt.figure()
plt.plot(df2["time"], df2["set_point"])
plt.plot(df2["time"], df2["gross_measure_variable"])
plt.plot(df2["time"], df2["filter_measure_variable"])
#plt.plot(df2["time"], df2["filter_measure_variable_2"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Position Test New Demo with UDP

# %%
df2 = pd.read_csv("zn_pid_tuned_pose_test1.csv")
plt.figure()
plt.plot(df2["time"], df2["set_point"])
plt.plot(df2["time"], df2["gross_measure_variable"])
plt.plot(df2["time"], df2["filter_measure_variable"])
#plt.plot(df2["time"], df2["filter_measure_variable_2"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df2 = pd.read_csv("zn_pid_tuned_pose_test1.csv")
plt.figure()
plt.plot(df2["time"], df2["set_point"])
plt.plot(df2["time"], df2["gross_measure_variable"])
plt.plot(df2["time"], df2["filter_measure_variable"])
#plt.plot(df2["time"], df2["filter_measure_variable_2"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df2 = pd.read_csv("zn_pid_tuned_pose_test1.csv")
plt.figure()
plt.plot(df2["time"], df2["set_point"])
plt.plot(df2["time"], df2["gross_measure_variable"])
plt.plot(df2["time"], df2["filter_measure_variable"])
#plt.plot(df2["time"], df2["filter_measure_variable_2"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df2 = pd.read_csv("zn_pid_tuned_pose_test1.csv")
plt.figure()
plt.plot(df2["time"], df2["set_point"])
plt.plot(df2["time"], df2["gross_measure_variable"])
plt.plot(df2["time"], df2["filter_measure_variable"])
#plt.plot(df2["time"], df2["filter_measure_variable_2"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df2 = pd.read_csv("zn_pid_tuned_pose_test_2.csv")
plt.figure()
plt.plot(df2["time"], df2["set_point"])
plt.plot(df2["time"], df2["gross_measure_variable"])
plt.plot(df2["time"], df2["filter_measure_variable"])
#plt.plot(df2["time"], df2["filter_measure_variable_2"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Slip TESTS

# %%
df2 = pd.read_csv("slip_demo.csv")
plt.figure()

"""
plt.plot(df2["time"], df2["fx"], label="fx")
plt.plot(df2["time"], df2["fy"], label="fy")
plt.plot(df2["time"], df2["fz"], label="fz")

plt.plot(df2["time"], df2["fx_filtered"], label="fx_filtered")
plt.plot(df2["time"], df2["fy_filtered"], label="fy_filtered")
plt.plot(df2["time"], df2["fz_filtered"], label="fz_filtered")
"""

magnitude =  df2["fx"]*df2["fy"]*df2["fz"]
magnitude_filtered =  df2["fx_filtered"]*df2["fy_filtered"]*df2["fz_filtered"]

plt.plot(df2["time"], magnitude, label="magnitude")
plt.plot(df2["time"], magnitude_filtered, label="magnitude_filtered")

plt.legend(loc="upper left")
#plt.plot(df2["time"], df2["filter_measure_variable_2"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df2 = pd.read_csv("slip_demo3.csv")
plt.figure()

"""
plt.plot(df2["time"], df2["fx"], label="fx")
plt.plot(df2["time"], df2["fy"], label="fy")
plt.plot(df2["time"], df2["fz"], label="fz")

plt.plot(df2["time"], df2["fx_filtered"], label="fx_filtered")
plt.plot(df2["time"], df2["fy_filtered"], label="fy_filtered")
plt.plot(df2["time"], df2["fz_filtered"], label="fz_filtered")
"""

magnitude =  df2["fx"]*df2["fy"]*df2["fz"]
magnitude_filtered =  df2["fx_filtered"]*df2["fy_filtered"]*df2["fz_filtered"]

plt.plot(df2["time"], magnitude, label="magnitude")
plt.plot(df2["time"], magnitude_filtered, label="magnitude_filtered")

plt.legend(loc="upper left")
#plt.plot(df2["time"], df2["filter_measure_variable_2"])
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
